# %% [markdown]
# Copyright 2021 Vector Informatik GmbH
# SPDX-License-Identifier: MIT
# Contact: khanlian.chung@vector.com

# %% [markdown]
# # Notebook for exploring and playing with saliency maps and backprop

# %%
# !pip install tensorflow numpy matplotlib
# Out:
# Requirement already satisfied: tensorflow in d:\repos\coderskitchen\venv\lib\site-packages (2.6.0)
# Requirement already satisfied: numpy in d:\repos\coderskitchen\venv\lib\site-packages (1.19.5)
# Requirement already satisfied: matplotlib in d:\repos\coderskitchen\venv\lib\site-packages (3.4.2)
# Requirement already satisfied: termcolor~=1.1.0 in d:\repos\coderskitchen\venv\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: protobuf>=3.9.2 in d:\repos\coderskitchen\venv\lib\site-packages (from tensorflow) (3.17.3)
# Requirement already satisfied: wrapt~=1.12.1 in d:\repos\coderskitchen\venv\lib\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in d:\repos\coderskitchen\venv\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: flatbuffers~=1.12.0 in d:\repos\coderskitchen\venv\lib\site-packages (from tensorflow) (1.12)
# Requirement already satisfied: google-pasta~=0.2 in d:\repos\coderskitchen\venv\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: wheel~=0.35 in d:\repos\coderskitchen\venv\lib\site-packages (from tensorflow) (0.37.0)
# Requirement already satisfied: keras~=2.6 in d:\repos\coderskitchen\venv\lib\site-packages (from tensorflow) (2.6.0)
# Requirement already satisfied: absl-py~=0.10 in d:\repos\coderskitchen\venv\lib\site-packages (from tensorflow) (0.13.0)
# Requirement already satisfied: gast==0.4.0 in d:\repos\coderskitchen\venv\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in d:\repos\coderskitchen\venv\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in d:\repos\coderskitchen\venv\lib\site-packages (from tensorflow) (3.7.4.3)
# Requirement already satisfied: tensorboard~=2.6 in d:\repos\coderskitchen\venv\lib\site-packages (from tensorflow) (2.6.0)
# Requirement already satisfied: astunparse~=1.6.3 in d:\repos\coderskitchen\venv\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: h5py~=3.1.0 in d:\repos\coderskitchen\venv\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: tensorflow-estimator~=2.6 in d:\repos\coderskitchen\venv\lib\site-packages (from tensorflow) (2.6.0)
# Requirement already satisfied: grpcio<2.0,>=1.37.0 in d:\repos\coderskitchen\venv\lib\site-packages (from tensorflow) (1.39.0)
# Requirement already satisfied: six~=1.15.0 in d:\repos\coderskitchen\venv\lib\site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: clang~=5.0 in d:\repos\coderskitchen\venv\lib\site-packages (from tensorflow) (5.0)
# Requirement already satisfied: setuptools>=41.0.0 in d:\repos\coderskitchen\venv\lib\site-packages (from tensorboard~=2.6->tensorflow) (57.2.0)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\repos\coderskitchen\venv\lib\site-packages (from tensorboard~=2.6->tensorflow) (2.26.0)
# Requirement already satisfied: werkzeug>=0.11.15 in d:\repos\coderskitchen\venv\lib\site-packages (from tensorboard~=2.6->tensorflow) (2.0.1)
# Requirement already satisfied: markdown>=2.6.8 in d:\repos\coderskitchen\venv\lib\site-packages (from tensorboard~=2.6->tensorflow) (3.3.4)
# Requirement already satisfied: google-auth<2,>=1.6.3 in d:\repos\coderskitchen\venv\lib\site-packages (from tensorboard~=2.6->tensorflow) (1.34.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in d:\repos\coderskitchen\venv\lib\site-packages (from tensorboard~=2.6->tensorflow) (0.4.5)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in d:\repos\coderskitchen\venv\lib\site-packages (from tensorboard~=2.6->tensorflow) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in d:\repos\coderskitchen\venv\lib\site-packages (from tensorboard~=2.6->tensorflow) (1.8.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in d:\repos\coderskitchen\venv\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\repos\coderskitchen\venv\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\repos\coderskitchen\venv\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in d:\repos\coderskitchen\venv\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\repos\coderskitchen\venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow) (0.4.8)
# Requirement already satisfied: idna<4,>=2.5 in d:\repos\coderskitchen\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in d:\repos\coderskitchen\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\repos\coderskitchen\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in d:\repos\coderskitchen\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2021.5.30)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\repos\coderskitchen\venv\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in d:\repos\coderskitchen\venv\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\repos\coderskitchen\venv\lib\site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: pillow>=6.2.0 in d:\repos\coderskitchen\venv\lib\site-packages (from matplotlib) (8.3.1)
# Requirement already satisfied: cycler>=0.10 in d:\repos\coderskitchen\venv\lib\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\repos\coderskitchen\venv\lib\site-packages (from matplotlib) (1.3.1)
# WARNING: You are using pip version 21.1.3; however, version 21.3 is available.
# You should consider upgrading via the 'd:\repos\coderskitchen\venv\scripts\python.exe -m pip install --upgrade pip' command.

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## A few helper functions to load an arbitrary image and generate a simple grey-value heatmap

# %% [markdown]
# Some helper function to pre and post processing the inputs.

# %%
def prep_input(path):
    image = tf.image.decode_png(tf.io.read_file(path))
    image = tf.expand_dims(image, axis=0)
    image = tf.cast(image, tf.float32)
    image = tf.image.resize(image, [224,224])
    return image

def norm_flat_image(img):
    grads_norm = img[:,:,0]+ img[:,:,1]+ img[:,:,2]
    grads_norm = (grads_norm - tf.reduce_min(grads_norm))/ (tf.reduce_max(grads_norm)- tf.reduce_min(grads_norm))
    return grads_norm
    
def get_lion():
    # Wikipedia lion image https://en.wikipedia.org/wiki/Lion#/media/File:Lion_waiting_in_Namibia.jpg
    # License: CC BY 2.0 https://creativecommons.org/licenses/by/2.0/deed.en
    import urllib.request
    filename = 'lion.jpg'
    img_url = r"https://upload.wikimedia.org/wikipedia/commons/7/73/Lion_waiting_in_Namibia.jpg"
    urllib.request.urlretrieve(img_url, filename)

def plot_maps(img1, img2,vmin=0.3,vmax=0.7, mix_val=2):
    f = plt.figure(figsize=(15,45))
    plt.subplot(1,3,1)
    plt.imshow(img1,vmin=vmin, vmax=vmax, cmap="gray")
    plt.axis("off")
    plt.subplot(1,3,2)
    plt.imshow(img2, cmap = "gray")
    plt.axis("off")
    plt.subplot(1,3,3)
    plt.imshow(img1*mix_val+img2/mix_val, cmap = "gray" )
    plt.axis("off")

# %% [markdown]
# This example is built upon a DenseNet201. But you can interchange it any other network. Simpliest way would be: change tf.keras.applications.densenet.DenseNet201() to another network such as tf.keras.applications.resnet.ResNet50(). Don't forget to change the preprocess_input accordingly. If you are interested in the imagenet data, have a look here: https://knowyourdata-tfds.withgoogle.com/#tab=STATS&dataset=imagenet2012

# %%
test_model = tf.keras.applications.densenet.DenseNet201()
#test_model.summary()
get_lion()
img_path = "lion.jpg"
input_img = prep_input(img_path)
input_img = tf.keras.applications.densenet.preprocess_input(input_img)
plt.imshow(norm_flat_image(input_img[0]), cmap = "gray")

# %%
result = test_model(input_img)
max_idx = tf.argmax(result,axis = 1)
tf.keras.applications.imagenet_utils.decode_predictions(result.numpy())
# Out:
# [[('n02129165', 'lion', 0.9963644),
#   ('n02106030', 'collie', 0.0027501779),
#   ('n02105855', 'Shetland_sheepdog', 0.00042291745),
#   ('n02130308', 'cheetah', 0.00014136593),
#   ('n02412080', 'ram', 5.228226e-05)]]

# %% [markdown]
# ## Vanilla backprop for saliency map:

# %% [markdown]
# After setting everything up, we have to explicitly instruct TF to calculate and keep the gradients for the input image input_img.

# %%
with tf.GradientTape() as tape:
    tape.watch(input_img)
    result = test_model(input_img)
    max_score = result[0,max_idx[0]]
grads = tape.gradient(max_score, input_img)

# %%
plot_maps(norm_flat_image(grads[0]), norm_flat_image(input_img[0]))

# %% [markdown]
# ## If you want to play around with different image windows, you can use napari

# %%
# !pip install napari
import napari
viewer = napari.view_image(norm_flat_image(grads[0]))
viewer.add_image(input_img)
# Out:
# Requirement already satisfied: napari in d:\repos\coderskitchen\venv\lib\site-packages (0.4.10)
# Requirement already satisfied: qtpy>=1.7.0 in d:\repos\coderskitchen\venv\lib\site-packages (from napari) (1.9.0)
# Requirement already satisfied: imageio>=2.5.0 in d:\repos\coderskitchen\venv\lib\site-packages (from napari) (2.9.0)
# Requirement already satisfied: dask[array]!=2.28.0,>=2.1.0 in d:\repos\coderskitchen\venv\lib\site-packages (from napari) (2021.8.1)
# Requirement already satisfied: tifffile>=2020.2.16 in d:\repos\coderskitchen\venv\lib\site-packages (from napari) (2021.8.8)
# Requirement already satisfied: typing-extensions in d:\repos\coderskitchen\venv\lib\site-packages (from napari) (3.7.4.3)
# Requirement already satisfied: wrapt>=1.11.1 in d:\repos\coderskitchen\venv\lib\site-packages (from napari) (1.12.1)
# Requirement already satisfied: appdirs>=1.4.4 in d:\repos\coderskitchen\venv\lib\site-packages (from napari) (1.4.4)
# Requirement already satisfied: magicgui>=0.2.6 in d:\repos\coderskitchen\venv\lib\site-packages (from napari) (0.2.10)
# Requirement already satisfied: numpy>=1.16.5 in d:\repos\coderskitchen\venv\lib\site-packages (from napari) (1.19.5)
# Requirement already satisfied: cachey>=0.2.1 in d:\repos\coderskitchen\venv\lib\site-packages (from napari) (0.2.1)
# Requirement already satisfied: napari-plugin-engine>=0.1.9 in d:\repos\coderskitchen\venv\lib\site-packages (from napari) (0.1.9)
# Requirement already satisfied: psutil>=5.0 in d:\repos\coderskitchen\venv\lib\site-packages (from napari) (5.8.0)
# Requirement already satisfied: pint>=0.17 in d:\repos\coderskitchen\venv\lib\site-packages (from napari) (0.17)
# Requirement already satisfied: PyOpenGL>=3.1.0 in d:\repos\coderskitchen\venv\lib\site-packages (from napari) (3.1.5)
# Requirement already satisfied: napari-console>=0.0.3 in d:\repos\coderskitchen\venv\lib\site-packages (from napari) (0.0.3)
# Requirement already satisfied: numpydoc>=0.9.2 in d:\repos\coderskitchen\venv\lib\site-packages (from napari) (1.1.0)
# Requirement already satisfied: scipy>=1.2.0 in d:\repos\coderskitchen\venv\lib\site-packages (from napari) (1.7.1)
# Requirement already satisfied: PyYAML>=5.1 in d:\repos\coderskitchen\venv\lib\site-packages (from napari) (5.4.1)
# Requirement already satisfied: jsonschema>=3.2.0 in d:\repos\coderskitchen\venv\lib\site-packages (from napari) (3.2.0)
# Requirement already satisfied: vispy>=0.6.4 in d:\repos\coderskitchen\venv\lib\site-packages (from napari) (0.8.0)
# Requirement already satisfied: Pillow!=7.1.0,!=7.1.1 in d:\repos\coderskitchen\venv\lib\site-packages (from napari) (8.3.1)
# Requirement already satisfied: napari-svg>=0.1.4 in d:\repos\coderskitchen\venv\lib\site-packages (from napari) (0.1.5)
# Requirement already satisfied: toolz>=0.10.0 in d:\repos\coderskitchen\venv\lib\site-packages (from napari) (0.11.1)
# Requirement already satisfied: pydantic>=1.8.1 in d:\repos\coderskitchen\venv\lib\site-packages (from napari) (1.8.2)
# Requirement already satisfied: tqdm>=4.56.0 in d:\repos\coderskitchen\venv\lib\site-packages (from napari) (4.62.1)
# Requirement already satisfied: heapdict in d:\repos\coderskitchen\venv\lib\site-packages (from cachey>=0.2.1->napari) (1.0.1)
# Requirement already satisfied: fsspec>=0.6.0 in d:\repos\coderskitchen\venv\lib\site-packages (from dask[array]!=2.28.0,>=2.1.0->napari) (2021.7.0)
# Requirement already satisfied: packaging>=20.0 in d:\repos\coderskitchen\venv\lib\site-packages (from dask[array]!=2.28.0,>=2.1.0->napari) (21.0)
# Requirement already satisfied: partd>=0.3.10 in d:\repos\coderskitchen\venv\lib\site-packages (from dask[array]!=2.28.0,>=2.1.0->napari) (1.2.0)
# Requirement already satisfied: cloudpickle>=1.1.1 in d:\repos\coderskitchen\venv\lib\site-packages (from dask[array]!=2.28.0,>=2.1.0->napari) (1.6.0)
# Requirement already satisfied: six>=1.11.0 in d:\repos\coderskitchen\venv\lib\site-packages (from jsonschema>=3.2.0->napari) (1.15.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in d:\repos\coderskitchen\venv\lib\site-packages (from jsonschema>=3.2.0->napari) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in d:\repos\coderskitchen\venv\lib\site-packages (from jsonschema>=3.2.0->napari) (21.2.0)
# Requirement already satisfied: setuptools in d:\repos\coderskitchen\venv\lib\site-packages (from jsonschema>=3.2.0->napari) (57.2.0)
# Requirement already satisfied: docstring-parser in d:\repos\coderskitchen\venv\lib\site-packages (from magicgui>=0.2.6->napari) (0.10)
# Requirement already satisfied: IPython>=7.7.0 in d:\repos\coderskitchen\venv\lib\site-packages (from napari-console>=0.0.3->napari) (7.25.0)
# Requirement already satisfied: ipykernel>=5.2.0 in d:\repos\coderskitchen\venv\lib\site-packages (from napari-console>=0.0.3->napari) (6.0.2)
# Requirement already satisfied: qtconsole!=4.7.6,>=4.5.1 in d:\repos\coderskitchen\venv\lib\site-packages (from napari-console>=0.0.3->napari) (5.1.1)
# Requirement already satisfied: traitlets<6.0,>=4.1.0 in d:\repos\coderskitchen\venv\lib\site-packages (from ipykernel>=5.2.0->napari-console>=0.0.3->napari) (5.0.5)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in d:\repos\coderskitchen\venv\lib\site-packages (from ipykernel>=5.2.0->napari-console>=0.0.3->napari) (0.1.2)
# Requirement already satisfied: tornado<7.0,>=4.2 in d:\repos\coderskitchen\venv\lib\site-packages (from ipykernel>=5.2.0->napari-console>=0.0.3->napari) (6.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in d:\repos\coderskitchen\venv\lib\site-packages (from ipykernel>=5.2.0->napari-console>=0.0.3->napari) (1.3.0)
# Requirement already satisfied: jupyter-client<7.0 in d:\repos\coderskitchen\venv\lib\site-packages (from ipykernel>=5.2.0->napari-console>=0.0.3->napari) (6.1.12)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in d:\repos\coderskitchen\venv\lib\site-packages (from IPython>=7.7.0->napari-console>=0.0.3->napari) (3.0.19)
# Requirement already satisfied: jedi>=0.16 in d:\repos\coderskitchen\venv\lib\site-packages (from IPython>=7.7.0->napari-console>=0.0.3->napari) (0.18.0)
# Requirement already satisfied: colorama in d:\repos\coderskitchen\venv\lib\site-packages (from IPython>=7.7.0->napari-console>=0.0.3->napari) (0.4.4)
# Requirement already satisfied: backcall in d:\repos\coderskitchen\venv\lib\site-packages (from IPython>=7.7.0->napari-console>=0.0.3->napari) (0.2.0)
# Requirement already satisfied: pickleshare in d:\repos\coderskitchen\venv\lib\site-packages (from IPython>=7.7.0->napari-console>=0.0.3->napari) (0.7.5)
# Requirement already satisfied: decorator in d:\repos\coderskitchen\venv\lib\site-packages (from IPython>=7.7.0->napari-console>=0.0.3->napari) (5.0.9)
# Requirement already satisfied: pygments in d:\repos\coderskitchen\venv\lib\site-packages (from IPython>=7.7.0->napari-console>=0.0.3->napari) (2.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in d:\repos\coderskitchen\venv\lib\site-packages (from jedi>=0.16->IPython>=7.7.0->napari-console>=0.0.3->napari) (0.8.2)
# Requirement already satisfied: pyzmq>=13 in d:\repos\coderskitchen\venv\lib\site-packages (from jupyter-client<7.0->ipykernel>=5.2.0->napari-console>=0.0.3->napari) (22.1.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in d:\repos\coderskitchen\venv\lib\site-packages (from jupyter-client<7.0->ipykernel>=5.2.0->napari-console>=0.0.3->napari) (4.7.1)
# Requirement already satisfied: python-dateutil>=2.1 in d:\repos\coderskitchen\venv\lib\site-packages (from jupyter-client<7.0->ipykernel>=5.2.0->napari-console>=0.0.3->napari) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in d:\repos\coderskitchen\venv\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<7.0->ipykernel>=5.2.0->napari-console>=0.0.3->napari) (301)
# Requirement already satisfied: Jinja2>=2.3 in d:\repos\coderskitchen\venv\lib\site-packages (from numpydoc>=0.9.2->napari) (3.0.1)
# Requirement already satisfied: sphinx>=1.6.5 in d:\repos\coderskitchen\venv\lib\site-packages (from numpydoc>=0.9.2->napari) (4.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\repos\coderskitchen\venv\lib\site-packages (from Jinja2>=2.3->numpydoc>=0.9.2->napari) (2.0.1)
# Requirement already satisfied: pyparsing>=2.0.2 in d:\repos\coderskitchen\venv\lib\site-packages (from packaging>=20.0->dask[array]!=2.28.0,>=2.1.0->napari) (2.4.7)
# Requirement already satisfied: locket in d:\repos\coderskitchen\venv\lib\site-packages (from partd>=0.3.10->dask[array]!=2.28.0,>=2.1.0->napari) (0.2.1)
# Requirement already satisfied: wcwidth in d:\repos\coderskitchen\venv\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython>=7.7.0->napari-console>=0.0.3->napari) (0.2.5)
# Requirement already satisfied: ipython-genutils in d:\repos\coderskitchen\venv\lib\site-packages (from qtconsole!=4.7.6,>=4.5.1->napari-console>=0.0.3->napari) (0.2.0)
# Requirement already satisfied: sphinxcontrib-qthelp in d:\repos\coderskitchen\venv\lib\site-packages (from sphinx>=1.6.5->numpydoc>=0.9.2->napari) (1.0.3)
# Requirement already satisfied: sphinxcontrib-jsmath in d:\repos\coderskitchen\venv\lib\site-packages (from sphinx>=1.6.5->numpydoc>=0.9.2->napari) (1.0.1)
# Requirement already satisfied: sphinxcontrib-devhelp in d:\repos\coderskitchen\venv\lib\site-packages (from sphinx>=1.6.5->numpydoc>=0.9.2->napari) (1.0.2)
# Requirement already satisfied: docutils<0.18,>=0.14 in d:\repos\coderskitchen\venv\lib\site-packages (from sphinx>=1.6.5->numpydoc>=0.9.2->napari) (0.17.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in d:\repos\coderskitchen\venv\lib\site-packages (from sphinx>=1.6.5->numpydoc>=0.9.2->napari) (2.0.0)
# Requirement already satisfied: requests>=2.5.0 in d:\repos\coderskitchen\venv\lib\site-packages (from sphinx>=1.6.5->numpydoc>=0.9.2->napari) (2.26.0)
# Requirement already satisfied: imagesize in d:\repos\coderskitchen\venv\lib\site-packages (from sphinx>=1.6.5->numpydoc>=0.9.2->napari) (1.2.0)
# Requirement already satisfied: snowballstemmer>=1.1 in d:\repos\coderskitchen\venv\lib\site-packages (from sphinx>=1.6.5->numpydoc>=0.9.2->napari) (2.1.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in d:\repos\coderskitchen\venv\lib\site-packages (from sphinx>=1.6.5->numpydoc>=0.9.2->napari) (1.1.5)
# Requirement already satisfied: alabaster<0.8,>=0.7 in d:\repos\coderskitchen\venv\lib\site-packages (from sphinx>=1.6.5->numpydoc>=0.9.2->napari) (0.7.12)
# Requirement already satisfied: sphinxcontrib-applehelp in d:\repos\coderskitchen\venv\lib\site-packages (from sphinx>=1.6.5->numpydoc>=0.9.2->napari) (1.0.2)
# Requirement already satisfied: babel>=1.3 in d:\repos\coderskitchen\venv\lib\site-packages (from sphinx>=1.6.5->numpydoc>=0.9.2->napari) (2.9.1)
# Requirement already satisfied: pytz>=2015.7 in d:\repos\coderskitchen\venv\lib\site-packages (from babel>=1.3->sphinx>=1.6.5->numpydoc>=0.9.2->napari) (2021.1)
# Requirement already satisfied: certifi>=2017.4.17 in d:\repos\coderskitchen\venv\lib\site-packages (from requests>=2.5.0->sphinx>=1.6.5->numpydoc>=0.9.2->napari) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\repos\coderskitchen\venv\lib\site-packages (from requests>=2.5.0->sphinx>=1.6.5->numpydoc>=0.9.2->napari) (1.26.6)
# Requirement already satisfied: idna<4,>=2.5 in d:\repos\coderskitchen\venv\lib\site-packages (from requests>=2.5.0->sphinx>=1.6.5->numpydoc>=0.9.2->napari) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in d:\repos\coderskitchen\venv\lib\site-packages (from requests>=2.5.0->sphinx>=1.6.5->numpydoc>=0.9.2->napari) (2.0.4)
# Requirement already satisfied: hsluv in d:\repos\coderskitchen\venv\lib\site-packages (from vispy>=0.6.4->napari) (5.0.2)
# Requirement already satisfied: kiwisolver in d:\repos\coderskitchen\venv\lib\site-packages (from vispy>=0.6.4->napari) (1.3.1)
# Requirement already satisfied: freetype-py in d:\repos\coderskitchen\venv\lib\site-packages (from vispy>=0.6.4->napari) (2.2.0)
# WARNING: You are using pip version 21.1.3; however, version 21.3 is available.
# You should consider upgrading via the 'd:\repos\coderskitchen\venv\scripts\python.exe -m pip install --upgrade pip' command.
# d:\Repos\CodersKitchen\venv\lib\site-packages\napari\_vispy\vispy_camera.py:109: RuntimeWarning: divide by zero encountered in true_divide
#   zoom = np.min(canvas_size / scale)
# <Image layer 'input_img' at 0x143394751c0>
